# %%
# Import the required libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from pandas.io.json import json_normalize

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
url_text = requests.get(url).text

# %%
soup = BeautifulSoup(url_text, 'lxml')

# %%
t = soup.find('table') # Looks like there is just one table so you need not use find_all

# %%
headers = t.find('tr') # Use find to load the row with the headers

# %%
col_h = headers.find_all('th')
col_names = []
for h in col_h:
    col_names.append(h.text) # Iterate over th to get the header name

# %%
col_names[2] = col_names[2][:-1]  # Last header apparently containns \n.. Remove the header
col_names
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
# Find all the td .. We need to pick three tds at a time . This will avoid iterating over tr 

rows = t.find_all('td')
rows[2].text  # Note the \n.. Code put in to while loop to remove this as shown below
# Out:
# 'Not assigned\n'

# %%
# Iterate over the tds to get the required columns
postcode = []
borough = []
neighbourhood = []
count = 0
while count < len(rows):
    postcode.append(rows[count].text)
    count+=1
    borough.append(rows[count].text)
    count+=1
    neighbourhood.append(rows[count].text[:-1])
    count+=1

# %%
#Create data frame with the three columns
data_dict = {'Postcode':postcode,
             'Borough':borough,
             'Neighbourhood':neighbourhood}
# Note that mentioning the columns will ensure that column order is maintained
df = pd.DataFrame(data_dict, columns=['Postcode','Borough','Neighbourhood'])

# %%
df.shape
# Out:
# (289, 3)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df = df[df['Borough']!='Not assigned'] # Removing all the entries where Borough is 'Not Assigned'

# %%
# Use numpy to replace Neighbourbood mentioned as  Not assigned with Borough
df["Neighbourhood"] = np.where(df["Neighbourhood"]=='Not assigned', df["Borough"],df["Neighbourhood"])
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
df.shape
# Out:
# (212, 3)

# %%
#  Adding semicolumn in the end of neighbourhood to have the neighbourhoods comma seperated while consolidating

df["Neighbourhood"] = df["Neighbourhood"] +','

# %%
# Verifying the total unique postcodes. This will be verifying against the csv file with the post code
len(set(df['Postcode']))
# Out:
# 103

# %%
# Run a group by based on post code and borough and sum it, which will concatenate the neighbourhoods 
df = df.groupby(['Postcode','Borough']).sum()
df.head()
# Out:
#                                               Neighbourhood
# Postcode Borough
# M1B      Scarborough                         Rouge,Malvern,
# M1C      Scarborough  Highland Creek,Rouge Hill,Port Union,
# M1E      Scarborough       Guildwood,Morningside,West Hill,
# M1G      Scarborough                                Woburn,
# M1H      Scarborough                             Cedarbrae,

# %%
df = df.reset_index() # Flatten the dataframe

# %%
# Remove the semi colon from the neighbourhood
df['Neighbourhood'] = df['Neighbourhood'].apply(lambda x: x[0:-1])

# %%
df.head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %%
# Gosh I wasted time using the google api. api gets timed out all the time. Foursqure api also provides decent 
# data but coursera gives option of only google api or the use of the CSV file provided. Hence used the CSV file
# Load thje file
geo_data = pd.read_csv('Geospatial_Coordinates.csv')
# Set the index to Postal code so that we can look up directly
geo_data.set_index('Postal Code',inplace=True)

def getlatlong(postalcode):
    lat = None
    long = None
    try:
        lat = geo_data.loc[postalcode][0]
    except:
        pass
    try:
        long = geo_data.loc[postalcode][1]
    except:
        pass
    return lat,long

# %%
df['latitude'] = df['Postcode'].apply(lambda x : getlatlong(x)[0]) # Add latitude column
df['longitude'] = df['Postcode'].apply(lambda x : getlatlong(x)[1])# Add longitude column

# %%
df.head()
# Out:
#   Postcode      Borough                         Neighbourhood   latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
df.shape
# Out:
# (103, 5)

# %%
df.head()
# Out:
#   Postcode      Borough                         Neighbourhood   latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
# Import folium and load th map for Toronto, Canada

import folium
address = 'Toronto,Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude

# %%
map_t = folium.Map(location = [latitude, longitude], zoom_start = 10)

# %%
# Mark all the Borough / Neighbourhoods using folium
for lat,long,borough,neighbourhood in zip(df['latitude'],df['longitude'],df['Borough'],df['Neighbourhood']):    
   label = '{}, {}'.format(neighbourhood, borough)
   label = folium.Popup(label, parse_html=True)
   folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#4186FF',
        fill_opacity=0.7).add_to(map_t)

# %%
map_t
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df['Borough'].unique()
# Out:
# array(['Scarborough', 'North York', 'East York', 'East Toronto',
#        'Central Toronto', 'Downtown Toronto', 'York', 'West Toronto',
#        "Queen's Park", 'Mississauga', 'Etobicoke'], dtype=object)

# %%
#Picked the first element for analysis to make the map bit more readable and ease -->Scarborough
address = 'Scarborough,Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude,longitude)
# Out:
# 43.773077 -79.257774

# %%
df_scarborough = df[df['Borough']=='Scarborough']

# %%
df_scarborough
# Out:
#    Postcode      Borough                                      Neighbourhood  \
# 0       M1B  Scarborough                                      Rouge,Malvern
# 1       M1C  Scarborough               Highland Creek,Rouge Hill,Port Union
# 2       M1E  Scarborough                    Guildwood,Morningside,West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough          East Birchmount Park,Ionview,Kennedy Park
# 7       M1L  Scarborough                      Clairlea,Golden Mile,Oakridge
# 8       M1M  Scarborough      Cliffcrest,Cliffside,Scarborough Village West
# 9       M1N  Scarborough                         Birch Cliff,Cliffside West
# 10      M1P  Scarborough  Dorset Park,Scarborough Town Centre,Wexford He...
# 11      M1R  Scarborough                                   Maryvale,Wexford
# 12      M1S  Scarborough                                          Agincourt
# 13      M1T  Scarborough              Clarks Corners,Sullivan,Tam O'Shanter
# 14      M1V  Scarborough  Agincourt North,L'Amoreaux East,Milliken,Steel...
# 15      M1W  Scarborough                       L'Amoreaux West,Steeles West
# 16      M1X  Scarborough                                        Upper Rouge
#
#      latitude  longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304
# 11  43.750072 -79.295849
# 12  43.794200 -79.262029
# 13  43.781638 -79.304302
# 14  43.815252 -79.284577
# 15  43.799525 -79.318389
# 16  43.836125 -79.205636

# %%
map_scarborough = folium.Map(location = [latitude, longitude], zoom_start = 10)

# %%
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Mark all the neighbourhood for scarborough
for lat,long,borough,neighbourhood in zip(df_scarborough['latitude'],df_scarborough['longitude'],df_scarborough['Borough'],df_scarborough['Neighbourhood']):    
   label = '{}, {}'.format(neighbourhood, borough)
   label = folium.Popup(label, parse_html=True)
   folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#4186FF',
        fill_opacity=0.7).add_to(map_scarborough)

# %%
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Neighbourhood segmentation for Scarborough

# %% [markdown]
# 1. Aim to find out all the venues in and around .Scarborough
# 2. Find out the categories of each venue under each of the neighbourhoods
# 3. Find out the availability (mean againt the total) of the venues under each neighbourhood
# 4. Cluster the neighbourhood
# 5. Map it out using Folium and mark the different neighbourhoods in differnet colors based on the cluster

# %%
CLIENT_ID='ZOO51K0TRLO3V1BXETAEBMWHHIO2C0DXTW05UWSNGTBS5G0E'
CLIENT_SECRET='ODKWIW1VFAKDYQ1PQNNJQU1RQDCA2QMV0UNTHXJHPBCR422B'
VERSION='20181511'
LIMIT=30
RADIUS = 500

# %%
latitude = df_scarborough['latitude'][10]
longitude = df_scarborough['longitude'][10]

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, RADIUS, LIMIT)

# %%
results = requests.get(url).json()

# %%
results.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
results['response'].keys()
# Out:
# dict_keys(['venues', 'confident'])

# %%
results['response']['venues'][0].keys()
# Out:
# dict_keys(['id', 'name', 'location', 'categories', 'referralId', 'hasPerk'])

# %%
venues = results['response']['venues']
df_venues = json_normalize(venues)
df_venues.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...    False
# 1  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...    False
# 2  [{'id': '4f04ae1f2fb6e1c99f3db0ba', 'name': 'C...    False
# 3  [{'id': '52f2ab2ebcbc57f1066b8b44', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d122951735', 'name': 'E...    False
#
#                          id             location.address location.cc  \
# 0  5228afe611d2a57901449823                145 Nantucket          CA
# 1  4b920246f964a52045e333e3              300 Midwest Rd.          CA
# 2  5b1aa51b1fa763002cf54662           180 Nantucket Blvd          CA
# 3  5ba9050951950e002c2430d8  170 Nantucket Blvd. Unit #8          CA
# 4  4aec5e3bf964a52067c621e3            1306 Kennedy Road          CA
#
#   location.city location.country                  location.crossStreet  \
# 0   Scarborough           Canada                                   NaN
# 1   Scarborough           Canada                                   NaN
# 2       Toronto           Canada                                   NaN
# 3   Scarborough           Canada                                   NaN
# 4   Scarborough           Canada  btwn Ellesmere Rd. & Lawrence Ave. E
#
#    location.distance                          location.formattedAddress  \
# 0                 80            [145 Nantucket, Scarborough ON, Canada]
# 1                288  [300 Midwest Rd., Scarborough ON M1P 3A9, Canada]
# 2                201   [180 Nantucket Blvd, Toronto ON M1P 4R6, Canada]
# 3                184  [170 Nantucket Blvd. Unit #8, Scarborough ON M...
# 4                501  [1306 Kennedy Road (btwn Ellesmere Rd. & Lawre...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.75715341768399...     43.757153
# 1  [{'label': 'display', 'lat': 43.75947159983688...     43.759472
# 2  [{'label': 'display', 'lat': 43.757644, 'lng':...     43.757644
# 3  [{'label': 'display', 'lat': 43.75743, 'lng': ...     43.757430
# 4  [{'label': 'display', 'lat': 43.75935629419452...     43.759356
#
#    location.lng location.postalCode location.state                   name  \
# 0    -79.274237                 NaN             ON              TireCraft
# 1    -79.271121             M1P 3A9             ON       Mill St. Brewery
# 2    -79.275789             M1P 4R6             ON          EE Auto Group
# 3    -79.275600             M1P 4R6             ON  The Friendly Mechanic
# 4    -79.278931             M1P 2L5             ON       Canada Computers
#
#      referralId
# 0  v-1543401368
# 1  v-1543401368
# 2  v-1543401368
# 3  v-1543401368
# 4  v-1543401368

# %%
colnames = ['name','categories']+[col for col in df_venues.columns if col.startswith('location')]+['id']
df_venues_updated = df_venues.loc[:,colnames]

# %%
def get_category(row):
    category_list =  row['categories']
    if len(category_list)==0:
        return None
    else:
        return category_list[0]['name']

# %%
df_venues_updated['categories'] = df_venues_updated.apply(get_category,axis=1)

# %%
df_venues_updated.columns = [col.split('.')[-1] for col in df_venues_updated.columns]

# %%
df_venues_updated.head()
# Out:
#                     name         categories                      address  cc  \
# 0              TireCraft    Automotive Shop                145 Nantucket  CA
# 1       Mill St. Brewery            Brewery              300 Midwest Rd.  CA
# 2          EE Auto Group           Car Wash           180 Nantucket Blvd  CA
# 3  The Friendly Mechanic        Auto Garage  170 Nantucket Blvd. Unit #8  CA
# 4       Canada Computers  Electronics Store            1306 Kennedy Road  CA
#
#           city country                           crossStreet  distance  \
# 0  Scarborough  Canada                                   NaN        80
# 1  Scarborough  Canada                                   NaN       288
# 2      Toronto  Canada                                   NaN       201
# 3  Scarborough  Canada                                   NaN       184
# 4  Scarborough  Canada  btwn Ellesmere Rd. & Lawrence Ave. E       501
#
#                                     formattedAddress  \
# 0            [145 Nantucket, Scarborough ON, Canada]
# 1  [300 Midwest Rd., Scarborough ON M1P 3A9, Canada]
# 2   [180 Nantucket Blvd, Toronto ON M1P 4R6, Canada]
# 3  [170 Nantucket Blvd. Unit #8, Scarborough ON M...
# 4  [1306 Kennedy Road (btwn Ellesmere Rd. & Lawre...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.75715341768399...  43.757153 -79.274237
# 1  [{'label': 'display', 'lat': 43.75947159983688...  43.759472 -79.271121
# 2  [{'label': 'display', 'lat': 43.757644, 'lng':...  43.757644 -79.275789
# 3  [{'label': 'display', 'lat': 43.75743, 'lng': ...  43.757430 -79.275600
# 4  [{'label': 'display', 'lat': 43.75935629419452...  43.759356 -79.278931
#
#   postalCode state                        id
# 0        NaN    ON  5228afe611d2a57901449823
# 1    M1P 3A9    ON  4b920246f964a52045e333e3
# 2    M1P 4R6    ON  5b1aa51b1fa763002cf54662
# 3    M1P 4R6    ON  5ba9050951950e002c2430d8
# 4    M1P 2L5    ON  4aec5e3bf964a52067c621e3

# %%
#Group the rows based on the categories. Looks like Automotive shop is the prominent one in thi location
df_venues_updated.groupby('categories').count()
# Out:
#                         name  address  cc  city  country  crossStreet  \
# categories
# Arts & Crafts Store        1        1   1     1        1            1
# Auto Garage                1        1   1     1        1            0
# Automotive Shop           10        6  10     6       10            1
# Brewery                    1        1   1     1        1            0
# Building                   2        1   2     1        2            0
# Car Wash                   1        1   1     1        1            0
# Doctor's Office            1        0   1     0        1            0
# Electronics Store          1        1   1     1        1            1
# Factory                    1        0   1     0        1            0
# Furniture / Home Store     1        1   1     1        1            0
# Hardware Store             1        1   1     1        1            0
# Office                     1        1   1     1        1            0
# Performing Arts Venue      1        1   1     1        1            1
#
#                         distance  formattedAddress  labeledLatLngs  lat  lng  \
# categories
# Arts & Crafts Store            1                 1               1    1    1
# Auto Garage                    1                 1               1    1    1
# Automotive Shop               10                10              10   10   10
# Brewery                        1                 1               1    1    1
# Building                       2                 2               2    2    2
# Car Wash                       1                 1               1    1    1
# Doctor's Office                1                 1               1    1    1
# Electronics Store              1                 1               1    1    1
# Factory                        1                 1               1    1    1
# Furniture / Home Store         1                 1               1    1    1
# Hardware Store                 1                 1               1    1    1
# Office                         1                 1               1    1    1
# Performing Arts Venue          1                 1               1    1    1
#
#                         postalCode  state  id
# categories
# Arts & Crafts Store              1      1   1
# Auto Garage                      1      1   1
# Automotive Shop                  2      7  10
# Brewery                          1      1   1
# Building                         1      2   2
# Car Wash                         1      1   1
# Doctor's Office                  0      0   1
# Electronics Store                1      1   1
# Factory                          0      0   1
# Furniture / Home Store           1      1   1
# Hardware Store                   1      1   1
# Office                           0      1   1
# Performing Arts Venue            1      1   1

# %%
#Collect Venues for all the neighbourhoods

df_venue_all = pd.DataFrame()
for neighbourhood,neigh_lat,neigh_long  in zip(df_scarborough['Neighbourhood'],df_scarborough['latitude'],df_scarborough['longitude']):
    #print(neigh_lat,neigh_long)
    neighbourhood_lst.append(neighbourhood)
    neigh_lat_lst.append(neigh_lat)
    neigh_long_lst.append(neigh_long)
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, neigh_lat, neigh_long, VERSION, RADIUS, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    df_venues = json_normalize(venues)
    #print(df_venues.shape)
    df_venues['Neighbourhood'] = neighbourhood
    df_venues['Neigh_latitude'] = neigh_lat
    df_venues['Neigh_longitude'] = neigh_long
    df_venue_all = df_venue_all.append(df_venues)
    #print(df_venue_all.shape)

# %%
df_venue_all['categories'] = df_venue_all.apply(get_category,axis=1)

# %%
df_venues_all_grp = df_venue_all.groupby(['Neighbourhood','categories']).count()

# %%
df_venues_all_grp.reset_index(inplace=True)

# %%
'''
#Below code should not be cut loose. Daily quota will get exhausted and will get stuck

ratings=[]
for vid in df_venues_updated['id']:
    VENUE_ID = vid
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(VENUE_ID,CLIENT_ID, CLIENT_SECRET,VERSION)
    result = requests.get(url).json()
    if 'rating' in result['response']['venue'].keys():
        r = result['response']['venue']['rating']
        ratings.append(r)
    else:
        ratings.append('0')

df_venues_updated['Ratings'] = ratings
#Storing the values to CSV so that api need not be called againg and again
#df_venues_updated.to_csv('df_venues_updated.csv')
'''
# Out:
# "\n#Below code should not be cut loose. Daily quota will get exhausted and will get stuck\n\nratings=[]\nfor vid in df_venues_updated['id']:\n    VENUE_ID = vid\n    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(VENUE_ID,CLIENT_ID, CLIENT_SECRET,VERSION)\n    result = requests.get(url).json()\n    if 'rating' in result['response']['venue'].keys():\n        r = result['response']['venue']['rating']\n        ratings.append(r)\n    else:\n        ratings.append('0')\n\ndf_venues_updated['Ratings'] = ratings\n#Storing the values to CSV so that api need not be called againg and again\n#df_venues_updated.to_csv('df_venues_updated.csv')\n"

# %%
df_venues_all_grp_d = pd.get_dummies(df_venues_all_grp[['categories']], prefix="", prefix_sep="")


df_venues_all_grp_d['Neighbourhood'] = df_venues_all_grp['Neighbourhood']

# %%
df_venues_all_grp_d_mean = df_venues_all_grp_d.groupby('Neighbourhood').mean() # summation of each row needs to be one. Higher the
#number, more prominant in is the category.  We now have numerical values which can be used to get the distance meaurement while runing kmeans
df_venues_all_grp_d_mean
# Out:
#                                                     Advertising Agency  \
# Neighbourhood
# Agincourt                                                     0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...            0.000000
# Birch Cliff,Cliffside West                                    0.000000
# Cedarbrae                                                     0.000000
# Clairlea,Golden Mile,Oakridge                                 0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                         0.000000
# Cliffcrest,Cliffside,Scarborough Village West                 0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...            0.000000
# East Birchmount Park,Ionview,Kennedy Park                     0.000000
# Guildwood,Morningside,West Hill                               0.000000
# Highland Creek,Rouge Hill,Port Union                          0.000000
# L'Amoreaux West,Steeles West                                  0.000000
# Maryvale,Wexford                                              0.000000
# Rouge,Malvern                                                 0.000000
# Scarborough Village                                           0.000000
# Upper Rouge                                                   0.066667
# Woburn                                                        0.000000
#
#                                                     Arts & Crafts Store  \
# Neighbourhood
# Agincourt                                                      0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...             0.062500
# Birch Cliff,Cliffside West                                     0.000000
# Cedarbrae                                                      0.000000
# Clairlea,Golden Mile,Oakridge                                  0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                          0.000000
# Cliffcrest,Cliffside,Scarborough Village West                  0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...             0.076923
# East Birchmount Park,Ionview,Kennedy Park                      0.000000
# Guildwood,Morningside,West Hill                                0.000000
# Highland Creek,Rouge Hill,Port Union                           0.000000
# L'Amoreaux West,Steeles West                                   0.000000
# Maryvale,Wexford                                               0.000000
# Rouge,Malvern                                                  0.000000
# Scarborough Village                                            0.000000
# Upper Rouge                                                    0.000000
# Woburn                                                         0.000000
#
#                                                     Assisted Living  \
# Neighbourhood
# Agincourt                                                  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...         0.000000
# Birch Cliff,Cliffside West                                 0.000000
# Cedarbrae                                                  0.000000
# Clairlea,Golden Mile,Oakridge                              0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                      0.000000
# Cliffcrest,Cliffside,Scarborough Village West              0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...         0.000000
# East Birchmount Park,Ionview,Kennedy Park                  0.000000
# Guildwood,Morningside,West Hill                            0.000000
# Highland Creek,Rouge Hill,Port Union                       0.066667
# L'Amoreaux West,Steeles West                               0.000000
# Maryvale,Wexford                                           0.000000
# Rouge,Malvern                                              0.000000
# Scarborough Village                                        0.000000
# Upper Rouge                                                0.000000
# Woburn                                                     0.047619
#
#                                                     Auto Dealership  \
# Neighbourhood
# Agincourt                                                  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...         0.000000
# Birch Cliff,Cliffside West                                 0.000000
# Cedarbrae                                                  0.000000
# Clairlea,Golden Mile,Oakridge                              0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                      0.043478
# Cliffcrest,Cliffside,Scarborough Village West              0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...         0.000000
# East Birchmount Park,Ionview,Kennedy Park                  0.000000
# Guildwood,Morningside,West Hill                            0.000000
# Highland Creek,Rouge Hill,Port Union                       0.000000
# L'Amoreaux West,Steeles West                               0.000000
# Maryvale,Wexford                                           0.000000
# Rouge,Malvern                                              0.000000
# Scarborough Village                                        0.000000
# Upper Rouge                                                0.066667
# Woburn                                                     0.000000
#
#                                                     Auto Garage  \
# Neighbourhood
# Agincourt                                              0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...     0.000000
# Birch Cliff,Cliffside West                             0.055556
# Cedarbrae                                              0.000000
# Clairlea,Golden Mile,Oakridge                          0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                  0.000000
# Cliffcrest,Cliffside,Scarborough Village West          0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...     0.076923
# East Birchmount Park,Ionview,Kennedy Park              0.000000
# Guildwood,Morningside,West Hill                        0.050000
# Highland Creek,Rouge Hill,Port Union                   0.000000
# L'Amoreaux West,Steeles West                           0.000000
# Maryvale,Wexford                                       0.000000
# Rouge,Malvern                                          0.000000
# Scarborough Village                                    0.000000
# Upper Rouge                                            0.000000
# Woburn                                                 0.000000
#
#                                                     Automotive Shop    Bakery  \
# Neighbourhood
# Agincourt                                                  0.050000  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...         0.000000  0.000000
# Birch Cliff,Cliffside West                                 0.000000  0.000000
# Cedarbrae                                                  0.000000  0.083333
# Clairlea,Golden Mile,Oakridge                              0.000000  0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                      0.043478  0.000000
# Cliffcrest,Cliffside,Scarborough Village West              0.000000  0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...         0.076923  0.000000
# East Birchmount Park,Ionview,Kennedy Park                  0.000000  0.000000
# Guildwood,Morningside,West Hill                            0.000000  0.000000
# Highland Creek,Rouge Hill,Port Union                       0.000000  0.000000
# L'Amoreaux West,Steeles West                               0.000000  0.000000
# Maryvale,Wexford                                           0.000000  0.071429
# Rouge,Malvern                                              0.000000  0.000000
# Scarborough Village                                        0.000000  0.000000
# Upper Rouge                                                0.000000  0.000000
# Woburn                                                     0.000000  0.000000
#
#                                                         Bank       Bar  \
# Neighbourhood
# Agincourt                                           0.000000  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...  0.000000  0.000000
# Birch Cliff,Cliffside West                          0.000000  0.000000
# Cedarbrae                                           0.083333  0.000000
# Clairlea,Golden Mile,Oakridge                       0.000000  0.000000
# Clarks Corners,Sullivan,Tam O'Shanter               0.043478  0.000000
# Cliffcrest,Cliffside,Scarborough Village West       0.000000  0.047619
# Dorset Park,Scarborough Town Centre,Wexford Hei...  0.000000  0.000000
# East Birchmount Park,Ionview,Kennedy Park           0.000000  0.000000
# Guildwood,Morningside,West Hill                     0.050000  0.000000
# Highland Creek,Rouge Hill,Port Union                0.000000  0.066667
# L'Amoreaux West,Steeles West                        0.041667  0.041667
# Maryvale,Wexford                                    0.000000  0.000000
# Rouge,Malvern                                       0.000000  0.000000
# Scarborough Village                                 0.000000  0.000000
# Upper Rouge                                         0.000000  0.000000
# Woburn                                              0.000000  0.000000
#
#                                                        Beach     ...       \
# Neighbourhood                                                    ...
# Agincourt                                           0.000000     ...
# Agincourt North,L'Amoreaux East,Milliken,Steele...  0.000000     ...
# Birch Cliff,Cliffside West                          0.000000     ...
# Cedarbrae                                           0.000000     ...
# Clairlea,Golden Mile,Oakridge                       0.000000     ...
# Clarks Corners,Sullivan,Tam O'Shanter               0.000000     ...
# Cliffcrest,Cliffside,Scarborough Village West       0.047619     ...
# Dorset Park,Scarborough Town Centre,Wexford Hei...  0.000000     ...
# East Birchmount Park,Ionview,Kennedy Park           0.000000     ...
# Guildwood,Morningside,West Hill                     0.000000     ...
# Highland Creek,Rouge Hill,Port Union                0.000000     ...
# L'Amoreaux West,Steeles West                        0.000000     ...
# Maryvale,Wexford                                    0.000000     ...
# Rouge,Malvern                                       0.000000     ...
# Scarborough Village                                 0.000000     ...
# Upper Rouge                                         0.000000     ...
# Woburn                                              0.000000     ...
#
#                                                     Theme Park  \
# Neighbourhood
# Agincourt                                             0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...    0.000000
# Birch Cliff,Cliffside West                            0.000000
# Cedarbrae                                             0.000000
# Clairlea,Golden Mile,Oakridge                         0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                 0.000000
# Cliffcrest,Cliffside,Scarborough Village West         0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...    0.000000
# East Birchmount Park,Ionview,Kennedy Park             0.000000
# Guildwood,Morningside,West Hill                       0.000000
# Highland Creek,Rouge Hill,Port Union                  0.000000
# L'Amoreaux West,Steeles West                          0.000000
# Maryvale,Wexford                                      0.000000
# Rouge,Malvern                                         0.000000
# Scarborough Village                                   0.000000
# Upper Rouge                                           0.000000
# Woburn                                                0.047619
#
#                                                     Thrift / Vintage Store  \
# Neighbourhood
# Agincourt                                                         0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...                0.000000
# Birch Cliff,Cliffside West                                        0.000000
# Cedarbrae                                                         0.000000
# Clairlea,Golden Mile,Oakridge                                     0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                             0.000000
# Cliffcrest,Cliffside,Scarborough Village West                     0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...                0.000000
# East Birchmount Park,Ionview,Kennedy Park                         0.000000
# Guildwood,Morningside,West Hill                                   0.000000
# Highland Creek,Rouge Hill,Port Union                              0.000000
# L'Amoreaux West,Steeles West                                      0.000000
# Maryvale,Wexford                                                  0.000000
# Rouge,Malvern                                                     0.000000
# Scarborough Village                                               0.000000
# Upper Rouge                                                       0.000000
# Woburn                                                            0.047619
#
#                                                     Trade School     Trail  \
# Neighbourhood
# Agincourt                                               0.000000  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...      0.000000  0.000000
# Birch Cliff,Cliffside West                              0.000000  0.000000
# Cedarbrae                                               0.000000  0.000000
# Clairlea,Golden Mile,Oakridge                           0.055556  0.055556
# Clarks Corners,Sullivan,Tam O'Shanter                   0.000000  0.000000
# Cliffcrest,Cliffside,Scarborough Village West           0.000000  0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...      0.000000  0.000000
# East Birchmount Park,Ionview,Kennedy Park               0.000000  0.000000
# Guildwood,Morningside,West Hill                         0.000000  0.000000
# Highland Creek,Rouge Hill,Port Union                    0.000000  0.000000
# L'Amoreaux West,Steeles West                            0.000000  0.000000
# Maryvale,Wexford                                        0.000000  0.000000
# Rouge,Malvern                                           0.000000  0.083333
# Scarborough Village                                     0.000000  0.000000
# Upper Rouge                                             0.000000  0.000000
# Woburn                                                  0.000000  0.000000
#
#                                                     Train Station  \
# Neighbourhood
# Agincourt                                                0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...       0.000000
# Birch Cliff,Cliffside West                               0.000000
# Cedarbrae                                                0.000000
# Clairlea,Golden Mile,Oakridge                            0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                    0.000000
# Cliffcrest,Cliffside,Scarborough Village West            0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...       0.000000
# East Birchmount Park,Ionview,Kennedy Park                0.058824
# Guildwood,Morningside,West Hill                          0.050000
# Highland Creek,Rouge Hill,Port Union                     0.000000
# L'Amoreaux West,Steeles West                             0.000000
# Maryvale,Wexford                                         0.000000
# Rouge,Malvern                                            0.000000
# Scarborough Village                                      0.000000
# Upper Rouge                                              0.000000
# Woburn                                                   0.000000
#
#                                                     Video Game Store  \
# Neighbourhood
# Agincourt                                                   0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...          0.000000
# Birch Cliff,Cliffside West                                  0.000000
# Cedarbrae                                                   0.000000
# Clairlea,Golden Mile,Oakridge                               0.055556
# Clarks Corners,Sullivan,Tam O'Shanter                       0.000000
# Cliffcrest,Cliffside,Scarborough Village West               0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...          0.000000
# East Birchmount Park,Ionview,Kennedy Park                   0.000000
# Guildwood,Morningside,West Hill                             0.000000
# Highland Creek,Rouge Hill,Port Union                        0.000000
# L'Amoreaux West,Steeles West                                0.000000
# Maryvale,Wexford                                            0.000000
# Rouge,Malvern                                               0.000000
# Scarborough Village                                         0.000000
# Upper Rouge                                                 0.000000
# Woburn                                                      0.000000
#
#                                                     Vietnamese Restaurant  \
# Neighbourhood
# Agincourt                                                        0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...               0.000000
# Birch Cliff,Cliffside West                                       0.000000
# Cedarbrae                                                        0.000000
# Clairlea,Golden Mile,Oakridge                                    0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                            0.000000
# Cliffcrest,Cliffside,Scarborough Village West                    0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...               0.000000
# East Birchmount Park,Ionview,Kennedy Park                        0.000000
# Guildwood,Morningside,West Hill                                  0.000000
# Highland Creek,Rouge Hill,Port Union                             0.000000
# L'Amoreaux West,Steeles West                                     0.000000
# Maryvale,Wexford                                                 0.071429
# Rouge,Malvern                                                    0.000000
# Scarborough Village                                              0.000000
# Upper Rouge                                                      0.000000
# Woburn                                                           0.000000
#
#                                                     Warehouse  Yoga Studio  \
# Neighbourhood
# Agincourt                                            0.000000     0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...   0.000000     0.000000
# Birch Cliff,Cliffside West                           0.000000     0.000000
# Cedarbrae                                            0.000000     0.000000
# Clairlea,Golden Mile,Oakridge                        0.000000     0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                0.000000     0.000000
# Cliffcrest,Cliffside,Scarborough Village West        0.000000     0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...   0.000000     0.000000
# East Birchmount Park,Ionview,Kennedy Park            0.000000     0.000000
# Guildwood,Morningside,West Hill                      0.000000     0.000000
# Highland Creek,Rouge Hill,Port Union                 0.000000     0.066667
# L'Amoreaux West,Steeles West                         0.000000     0.000000
# Maryvale,Wexford                                     0.071429     0.000000
# Rouge,Malvern                                        0.000000     0.000000
# Scarborough Village                                  0.000000     0.000000
# Upper Rouge                                          0.000000     0.000000
# Woburn                                               0.000000     0.000000
#
#                                                     Zoo Exhibit
# Neighbourhood
# Agincourt                                              0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...     0.000000
# Birch Cliff,Cliffside West                             0.000000
# Cedarbrae                                              0.000000
# Clairlea,Golden Mile,Oakridge                          0.000000
# Clarks Corners,Sullivan,Tam O'Shanter                  0.000000
# Cliffcrest,Cliffside,Scarborough Village West          0.000000
# Dorset Park,Scarborough Town Centre,Wexford Hei...     0.000000
# East Birchmount Park,Ionview,Kennedy Park              0.000000
# Guildwood,Morningside,West Hill                        0.000000
# Highland Creek,Rouge Hill,Port Union                   0.000000
# L'Amoreaux West,Steeles West                           0.000000
# Maryvale,Wexford                                       0.000000
# Rouge,Malvern                                          0.000000
# Scarborough Village                                    0.000000
# Upper Rouge                                            0.066667
# Woburn                                                 0.000000
#
# [17 rows x 139 columns]

# %%
# Define 5 clusters and find the cluster name
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline

num_clusters=5
k_means = KMeans(init = 'k-means++',n_clusters=num_clusters,n_init=12)
k_means.fit(df_venues_all_grp_d_mean)
df_venues_all_grp_d_mean['Cluster'] = k_means.labels_

# %%
df_venues_all_grp_d_mean.head()
# Out:
#                                                     Advertising Agency  \
# Neighbourhood
# Agincourt                                                          0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...                 0.0
# Birch Cliff,Cliffside West                                         0.0
# Cedarbrae                                                          0.0
# Clairlea,Golden Mile,Oakridge                                      0.0
#
#                                                     Arts & Crafts Store  \
# Neighbourhood
# Agincourt                                                        0.0000
# Agincourt North,L'Amoreaux East,Milliken,Steele...               0.0625
# Birch Cliff,Cliffside West                                       0.0000
# Cedarbrae                                                        0.0000
# Clairlea,Golden Mile,Oakridge                                    0.0000
#
#                                                     Assisted Living  \
# Neighbourhood
# Agincourt                                                       0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...              0.0
# Birch Cliff,Cliffside West                                      0.0
# Cedarbrae                                                       0.0
# Clairlea,Golden Mile,Oakridge                                   0.0
#
#                                                     Auto Dealership  \
# Neighbourhood
# Agincourt                                                       0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...              0.0
# Birch Cliff,Cliffside West                                      0.0
# Cedarbrae                                                       0.0
# Clairlea,Golden Mile,Oakridge                                   0.0
#
#                                                     Auto Garage  \
# Neighbourhood
# Agincourt                                              0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...     0.000000
# Birch Cliff,Cliffside West                             0.055556
# Cedarbrae                                              0.000000
# Clairlea,Golden Mile,Oakridge                          0.000000
#
#                                                     Automotive Shop    Bakery  \
# Neighbourhood
# Agincourt                                                      0.05  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...             0.00  0.000000
# Birch Cliff,Cliffside West                                     0.00  0.000000
# Cedarbrae                                                      0.00  0.083333
# Clairlea,Golden Mile,Oakridge                                  0.00  0.000000
#
#                                                         Bank  Bar  Beach  \
# Neighbourhood
# Agincourt                                           0.000000  0.0    0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...  0.000000  0.0    0.0
# Birch Cliff,Cliffside West                          0.000000  0.0    0.0
# Cedarbrae                                           0.083333  0.0    0.0
# Clairlea,Golden Mile,Oakridge                       0.000000  0.0    0.0
#
#                                                      ...     \
# Neighbourhood                                        ...
# Agincourt                                            ...
# Agincourt North,L'Amoreaux East,Milliken,Steele...   ...
# Birch Cliff,Cliffside West                           ...
# Cedarbrae                                            ...
# Clairlea,Golden Mile,Oakridge                        ...
#
#                                                     Thrift / Vintage Store  \
# Neighbourhood
# Agincourt                                                              0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...                     0.0
# Birch Cliff,Cliffside West                                             0.0
# Cedarbrae                                                              0.0
# Clairlea,Golden Mile,Oakridge                                          0.0
#
#                                                     Trade School     Trail  \
# Neighbourhood
# Agincourt                                               0.000000  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...      0.000000  0.000000
# Birch Cliff,Cliffside West                              0.000000  0.000000
# Cedarbrae                                               0.000000  0.000000
# Clairlea,Golden Mile,Oakridge                           0.055556  0.055556
#
#                                                     Train Station  \
# Neighbourhood
# Agincourt                                                     0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...            0.0
# Birch Cliff,Cliffside West                                    0.0
# Cedarbrae                                                     0.0
# Clairlea,Golden Mile,Oakridge                                 0.0
#
#                                                     Video Game Store  \
# Neighbourhood
# Agincourt                                                   0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...          0.000000
# Birch Cliff,Cliffside West                                  0.000000
# Cedarbrae                                                   0.000000
# Clairlea,Golden Mile,Oakridge                               0.055556
#
#                                                     Vietnamese Restaurant  \
# Neighbourhood
# Agincourt                                                             0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...                    0.0
# Birch Cliff,Cliffside West                                            0.0
# Cedarbrae                                                             0.0
# Clairlea,Golden Mile,Oakridge                                         0.0
#
#                                                     Warehouse  Yoga Studio  \
# Neighbourhood
# Agincourt                                                 0.0          0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...        0.0          0.0
# Birch Cliff,Cliffside West                                0.0          0.0
# Cedarbrae                                                 0.0          0.0
# Clairlea,Golden Mile,Oakridge                             0.0          0.0
#
#                                                     Zoo Exhibit  Cluster
# Neighbourhood
# Agincourt                                                   0.0        1
# Agincourt North,L'Amoreaux East,Milliken,Steele...          0.0        4
# Birch Cliff,Cliffside West                                  0.0        3
# Cedarbrae                                                   0.0        0
# Clairlea,Golden Mile,Oakridge                               0.0        2
#
# [5 rows x 140 columns]

# %%
def add_color(cno):
    if cno==0:
        return '#30412e'
    elif cno==1:
        return '#ebf118'
    elif cno==2:
        return '#6b0ae8'
    elif cno==3:
        return '#2bf4e2'
    else:
        return '2bf4e2'

df_venues_all_grp_d_mean['color'] = df_venues_all_grp_d_mean['Cluster'].apply(add_color)

# %%
df_venues_all_grp_d_mean.head()
# Out:
#                                                     Advertising Agency  \
# Neighbourhood
# Agincourt                                                          0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...                 0.0
# Birch Cliff,Cliffside West                                         0.0
# Cedarbrae                                                          0.0
# Clairlea,Golden Mile,Oakridge                                      0.0
#
#                                                     Arts & Crafts Store  \
# Neighbourhood
# Agincourt                                                        0.0000
# Agincourt North,L'Amoreaux East,Milliken,Steele...               0.0625
# Birch Cliff,Cliffside West                                       0.0000
# Cedarbrae                                                        0.0000
# Clairlea,Golden Mile,Oakridge                                    0.0000
#
#                                                     Assisted Living  \
# Neighbourhood
# Agincourt                                                       0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...              0.0
# Birch Cliff,Cliffside West                                      0.0
# Cedarbrae                                                       0.0
# Clairlea,Golden Mile,Oakridge                                   0.0
#
#                                                     Auto Dealership  \
# Neighbourhood
# Agincourt                                                       0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...              0.0
# Birch Cliff,Cliffside West                                      0.0
# Cedarbrae                                                       0.0
# Clairlea,Golden Mile,Oakridge                                   0.0
#
#                                                     Auto Garage  \
# Neighbourhood
# Agincourt                                              0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...     0.000000
# Birch Cliff,Cliffside West                             0.055556
# Cedarbrae                                              0.000000
# Clairlea,Golden Mile,Oakridge                          0.000000
#
#                                                     Automotive Shop    Bakery  \
# Neighbourhood
# Agincourt                                                      0.05  0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...             0.00  0.000000
# Birch Cliff,Cliffside West                                     0.00  0.000000
# Cedarbrae                                                      0.00  0.083333
# Clairlea,Golden Mile,Oakridge                                  0.00  0.000000
#
#                                                         Bank  Bar  Beach  \
# Neighbourhood
# Agincourt                                           0.000000  0.0    0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...  0.000000  0.0    0.0
# Birch Cliff,Cliffside West                          0.000000  0.0    0.0
# Cedarbrae                                           0.083333  0.0    0.0
# Clairlea,Golden Mile,Oakridge                       0.000000  0.0    0.0
#
#                                                      ...     Trade School  \
# Neighbourhood                                        ...
# Agincourt                                            ...         0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...   ...         0.000000
# Birch Cliff,Cliffside West                           ...         0.000000
# Cedarbrae                                            ...         0.000000
# Clairlea,Golden Mile,Oakridge                        ...         0.055556
#
#                                                        Trail  Train Station  \
# Neighbourhood
# Agincourt                                           0.000000            0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...  0.000000            0.0
# Birch Cliff,Cliffside West                          0.000000            0.0
# Cedarbrae                                           0.000000            0.0
# Clairlea,Golden Mile,Oakridge                       0.055556            0.0
#
#                                                     Video Game Store  \
# Neighbourhood
# Agincourt                                                   0.000000
# Agincourt North,L'Amoreaux East,Milliken,Steele...          0.000000
# Birch Cliff,Cliffside West                                  0.000000
# Cedarbrae                                                   0.000000
# Clairlea,Golden Mile,Oakridge                               0.055556
#
#                                                     Vietnamese Restaurant  \
# Neighbourhood
# Agincourt                                                             0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...                    0.0
# Birch Cliff,Cliffside West                                            0.0
# Cedarbrae                                                             0.0
# Clairlea,Golden Mile,Oakridge                                         0.0
#
#                                                     Warehouse  Yoga Studio  \
# Neighbourhood
# Agincourt                                                 0.0          0.0
# Agincourt North,L'Amoreaux East,Milliken,Steele...        0.0          0.0
# Birch Cliff,Cliffside West                                0.0          0.0
# Cedarbrae                                                 0.0          0.0
# Clairlea,Golden Mile,Oakridge                             0.0          0.0
#
#                                                     Zoo Exhibit  Cluster  \
# Neighbourhood
# Agincourt                                                   0.0        1
# Agincourt North,L'Amoreaux East,Milliken,Steele...          0.0        4
# Birch Cliff,Cliffside West                                  0.0        3
# Cedarbrae                                                   0.0        0
# Clairlea,Golden Mile,Oakridge                               0.0        2
#
#                                                       color
# Neighbourhood
# Agincourt                                           #ebf118
# Agincourt North,L'Amoreaux East,Milliken,Steele...   2bf4e2
# Birch Cliff,Cliffside West                          #2bf4e2
# Cedarbrae                                           #30412e
# Clairlea,Golden Mile,Oakridge                       #6b0ae8
#
# [5 rows x 141 columns]

# %%
address = 'Scarborough,Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude,longitude)
# Out:
# 43.773077 -79.257774

# %%
map_scarborough = folium.Map(location = [latitude, longitude], zoom_start = 11)

# %%
for lat,long,borough,neighbourhood in zip(df_scarborough['latitude'],df_scarborough['longitude'],df_scarborough['Borough'],df_scarborough['Neighbourhood']):    
   label = '{}, {}'.format(neighbourhood, borough)
   label = folium.Popup(label, parse_html=True)
   folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color=df_venues_all_grp_d_mean.loc[neighbourhood,'color'],
        fill_opacity=0.7).add_to(map_scarborough) 
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
